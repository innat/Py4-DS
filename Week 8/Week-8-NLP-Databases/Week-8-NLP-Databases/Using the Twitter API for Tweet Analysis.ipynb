# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = 'Ae2bz1ETeBBGl5lWKehu2fx7O'
    Twitter['Consumer Secret'] = 'xX2tSMBRnXvxRhUbxCLog38deX9q1eEVFHBY0dGFpIYdxycO47'
    Twitter['Access Token'] = '2923075178-cH9NNFeuRxWhBZf8OJnxlOjTLkHycv7pXMyb1qm'
    Twitter['Access Token Secret'] = 'cdfQqfCGWnuzPqTfWyW3mS3s8sa4QvPCzDc9Y8h3vjle9'
    
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter = pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\mohammed innat\anaconda3\lib\site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001C496427160>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1 
US_WOE_ID = 23424768
LOCAL_WOE_ID = 455825

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id = WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id = US_WOE_ID)
local_trends = twitter_api.trends.place(_id = LOCAL_WOE_ID)

# %%
us_trends[:2]
# Out:
# [{'trends': [{'name': 'Vox Populi',
#     'url': 'http://twitter.com/search?q=%22Vox+Populi%22',
#     'promoted_content': None,
#     'query': '%22Vox+Populi%22',
#     'tweet_volume': None},
#    {'name': '#DiaDoProgramador',
#     'url': 'http://twitter.com/search?q=%23DiaDoProgramador',
#     'promoted_content': None,
#     'query': '%23DiaDoProgramador',
#     'tweet_volume': None},
#    {'name': '#QuintaDetremuraSDV',
#     'url': 'http://twitter.com/search?q=%23QuintaDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23QuintaDetremuraSDV',
#     'tweet_volume': 13895},
#    {'name': '#SupernaturalDay',
#     'url': 'http://twitter.com/search?q=%23SupernaturalDay',
#     'promoted_content': None,
#     'query': '%23SupernaturalDay',
#     'tweet_volume': None},
#    {'name': '#HappyBirthdayNiall',
#     'url': 'http://twitter.com/search?q=%23HappyBirthdayNiall',
#     'promoted_content': None,
#     'query': '%23HappyBirthdayNiall',
#     'tweet_volume': 112387},
#    {'name': 'Dias Toffoli',
#     'url': 'http://twitter.com/search?q=%22Dias+Toffoli%22',
#     'promoted_content': None,
#     'query': '%22Dias+Toffoli%22',
#     'tweet_volume': None},
#    {'name': '#LigadoNaCN',
#     'url': 'http://twitter.com/search?q=%23LigadoNaCN',
#     'promoted_content': None,
#     'query': '%23LigadoNaCN',
#     'tweet_volume': None},
#    {'name': 'Michael Jordan',
#     'url': 'http://twitter.com/search?q=%22Michael+Jordan%22',
#     'promoted_content': None,
#     'query': '%22Michael+Jordan%22',
#     'tweet_volume': None},
#    {'name': 'Carta Capital',
#     'url': 'http://twitter.com/search?q=%22Carta+Capital%22',
#     'promoted_content': None,
#     'query': '%22Carta+Capital%22',
#     'tweet_volume': None},
#    {'name': 'Maracanaú',
#     'url': 'http://twitter.com/search?q=Maracana%C3%BA',
#     'promoted_content': None,
#     'query': 'Maracana%C3%BA',
#     'tweet_volume': None},
#    {'name': 'Carlos Bolsonaro',
#     'url': 'http://twitter.com/search?q=%22Carlos+Bolsonaro%22',
#     'promoted_content': None,
#     'query': '%22Carlos+Bolsonaro%22',
#     'tweet_volume': None},
#    {'name': 'Tasso Jereissati',
#     'url': 'http://twitter.com/search?q=%22Tasso+Jereissati%22',
#     'promoted_content': None,
#     'query': '%22Tasso+Jereissati%22',
#     'tweet_volume': None},
#    {'name': 'Jávier Godinho',
#     'url': 'http://twitter.com/search?q=%22J%C3%A1vier+Godinho%22',
#     'promoted_content': None,
#     'query': '%22J%C3%A1vier+Godinho%22',
#     'tweet_volume': None},
#    {'name': 'Tirei Fernando Haddad',
#     'url': 'http://twitter.com/search?q=%22Tirei+Fernando+Haddad%22',
#     'promoted_content': None,
#     'query': '%22Tirei+Fernando+Haddad%22',
#     'tweet_volume': None},
#    {'name': 'Tirei Henrique Meirelles',
#     'url': 'http://twitter.com/search?q=%22Tirei+Henrique+Meirelles%22',
#     'promoted_content': None,
#     'query': '%22Tirei+Henrique+Meirelles%22',
#     'tweet_volume': None},
#    {'name': 'Dia Nacional da Cachaça',
#     'url': 'http://twitter.com/search?q=%22Dia+Nacional+da+Cacha%C3%A7a%22',
#     'promoted_content': None,
#     'query': '%22Dia+Nacional+da+Cacha%C3%A7a%22',
#     'tweet_volume': None},
#    {'name': 'Tirei Ciro Gomes',
#     'url': 'http://twitter.com/search?q=%22Tirei+Ciro+Gomes%22',
#     'promoted_content': None,
#     'query': '%22Tirei+Ciro+Gomes%22',
#     'tweet_volume': None},
#    {'name': "Hyuna e o E'Dawn",
#     'url': 'http://twitter.com/search?q=%22Hyuna+e+o+E%27Dawn%22',
#     'promoted_content': None,
#     'query': '%22Hyuna+e+o+E%27Dawn%22',
#     'tweet_volume': None},
#    {'name': 'Tirei João Amoedo',
#     'url': 'http://twitter.com/search?q=%22Tirei+Jo%C3%A3o+Amoedo%22',
#     'promoted_content': None,
#     'query': '%22Tirei+Jo%C3%A3o+Amoedo%22',
#     'tweet_volume': None},
#    {'name': 'Tirei José Maria Eymael',
#     'url': 'http://twitter.com/search?q=%22Tirei+Jos%C3%A9+Maria+Eymael%22',
#     'promoted_content': None,
#     'query': '%22Tirei+Jos%C3%A9+Maria+Eymael%22',
#     'tweet_volume': None},
#    {'name': 'Túnel Noel Rosa',
#     'url': 'http://twitter.com/search?q=%22T%C3%BAnel+Noel+Rosa%22',
#     'promoted_content': None,
#     'query': '%22T%C3%BAnel+Noel+Rosa%22',
#     'tweet_volume': None},
#    {'name': 'Corinthians',
#     'url': 'http://twitter.com/search?q=Corinthians',
#     'promoted_content': None,
#     'query': 'Corinthians',
#     'tweet_volume': 139970},
#    {'name': 'Fábio',
#     'url': 'http://twitter.com/search?q=F%C3%A1bio',
#     'promoted_content': None,
#     'query': 'F%C3%A1bio',
#     'tweet_volume': 50840},
#    {'name': 'Cássio',
#     'url': 'http://twitter.com/search?q=C%C3%A1ssio',
#     'promoted_content': None,
#     'query': 'C%C3%A1ssio',
#     'tweet_volume': 32208},
#    {'name': 'Barcos',
#     'url': 'http://twitter.com/search?q=Barcos',
#     'promoted_content': None,
#     'query': 'Barcos',
#     'tweet_volume': 12824},
#    {'name': 'Superman',
#     'url': 'http://twitter.com/search?q=Superman',
#     'promoted_content': None,
#     'query': 'Superman',
#     'tweet_volume': 290209},
#    {'name': 'El Salvador',
#     'url': 'http://twitter.com/search?q=%22El+Salvador%22',
#     'promoted_content': None,
#     'query': '%22El+Salvador%22',
#     'tweet_volume': 15425},
#    {'name': 'Dourado',
#     'url': 'http://twitter.com/search?q=Dourado',
#     'promoted_content': None,
#     'query': 'Dourado',
#     'tweet_volume': 20806},
#    {'name': 'Clayson',
#     'url': 'http://twitter.com/search?q=Clayson',
#     'promoted_content': None,
#     'query': 'Clayson',
#     'tweet_volume': None},
#    {'name': 'Lana',
#     'url': 'http://twitter.com/search?q=Lana',
#     'promoted_content': None,
#     'query': 'Lana',
#     'tweet_volume': 91789},
#    {'name': '#GTFO',
#     'url': 'http://twitter.com/search?q=%23GTFO',
#     'promoted_content': None,
#     'query': '%23GTFO',
#     'tweet_volume': 25205},
#    {'name': '#LuisaSonzaNoMorning',
#     'url': 'http://twitter.com/search?q=%23LuisaSonzaNoMorning',
#     'promoted_content': None,
#     'query': '%23LuisaSonzaNoMorning',
#     'tweet_volume': None},
#    {'name': '#MaisVoce',
#     'url': 'http://twitter.com/search?q=%23MaisVoce',
#     'promoted_content': None,
#     'query': '%23MaisVoce',
#     'tweet_volume': None},
#    {'name': '#BoulosResponde',
#     'url': 'http://twitter.com/search?q=%23BoulosResponde',
#     'promoted_content': None,
#     'query': '%23BoulosResponde',
#     'tweet_volume': None},
#    {'name': '#bomdiafoxquinta',
#     'url': 'http://twitter.com/search?q=%23bomdiafoxquinta',
#     'promoted_content': None,
#     'query': '%23bomdiafoxquinta',
#     'tweet_volume': None},
#    {'name': '#sabatinasnoGlobo',
#     'url': 'http://twitter.com/search?q=%23sabatinasnoGlobo',
#     'promoted_content': None,
#     'query': '%23sabatinasnoGlobo',
#     'tweet_volume': None},
#    {'name': '#98Esportes',
#     'url': 'http://twitter.com/search?q=%2398Esportes',
#     'promoted_content': None,
#     'query': '%2398Esportes',
#     'tweet_volume': None},
#    {'name': '#AppleEvent',
#     'url': 'http://twitter.com/search?q=%23AppleEvent',
#     'promoted_content': None,
#     'query': '%23AppleEvent',
#     'tweet_volume': 1053879},
#    {'name': '#FinalCantaComigo',
#     'url': 'http://twitter.com/search?q=%23FinalCantaComigo',
#     'promoted_content': None,
#     'query': '%23FinalCantaComigo',
#     'tweet_volume': 13221},
#    {'name': '#ÉVerdadeEsseBilete',
#     'url': 'http://twitter.com/search?q=%23%C3%89VerdadeEsseBilete',
#     'promoted_content': None,
#     'query': '%23%C3%89VerdadeEsseBilete',
#     'tweet_volume': 21700},
#    {'name': '#AnittaDigaNaoAoFascismo',
#     'url': 'http://twitter.com/search?q=%23AnittaDigaNaoAoFascismo',
#     'promoted_content': None,
#     'query': '%23AnittaDigaNaoAoFascismo',
#     'tweet_volume': 11160},
#    {'name': '#MarinersApartmentComplex',
#     'url': 'http://twitter.com/search?q=%23MarinersApartmentComplex',
#     'promoted_content': None,
#     'query': '%23MarinersApartmentComplex',
#     'tweet_volume': 18130},
#    {'name': '#AMAs',
#     'url': 'http://twitter.com/search?q=%23AMAs',
#     'promoted_content': None,
#     'query': '%23AMAs',
#     'tweet_volume': 765399},
#    {'name': '#AHSApocalypse',
#     'url': 'http://twitter.com/search?q=%23AHSApocalypse',
#     'promoted_content': None,
#     'query': '%23AHSApocalypse',
#     'tweet_volume': 126572},
#    {'name': '#ateofimdoanoeu',
#     'url': 'http://twitter.com/search?q=%23ateofimdoanoeu',
#     'promoted_content': None,
#     'query': '%23ateofimdoanoeu',
#     'tweet_volume': None}],
#   'as_of': '2018-09-13T13:37:23Z',
#   'created_at': '2018-09-13T13:32:00Z',
#   'locations': [{'name': 'Brazil', 'woeid': 23424768}]}]

# %%
trends = local_trends
print(type(trends))
print()
print(list(trends[0].keys()))
print()
print(trends[0]['locations'])
print()
print(trends[0]['trends'])
print()
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
#
# ['trends', 'as_of', 'created_at', 'locations']
#
# [{'name': 'Rio de Janeiro', 'woeid': 455825}]
#
# [{'name': 'Vox Populi', 'url': 'http://twitter.com/search?q=%22Vox+Populi%22', 'promoted_content': None, 'query': '%22Vox+Populi%22', 'tweet_volume': None}, {'name': '#DiaDoProgramador', 'url': 'http://twitter.com/search?q=%23DiaDoProgramador', 'promoted_content': None, 'query': '%23DiaDoProgramador', 'tweet_volume': None}, {'name': '#QuintaDetremuraSDV', 'url': 'http://twitter.com/search?q=%23QuintaDetremuraSDV', 'promoted_content': None, 'query': '%23QuintaDetremuraSDV', 'tweet_volume': 13895}, {'name': '#SupernaturalDay', 'url': 'http://twitter.com/search?q=%23SupernaturalDay', 'promoted_content': None, 'query': '%23SupernaturalDay', 'tweet_volume': None}, {'name': '#HappyBirthdayNiall', 'url': 'http://twitter.com/search?q=%23HappyBirthdayNiall', 'promoted_content': None, 'query': '%23HappyBirthdayNiall', 'tweet_volume': 112387}, {'name': 'Dias Toffoli', 'url': 'http://twitter.com/search?q=%22Dias+Toffoli%22', 'promoted_content': None, 'query': '%22Dias+Toffoli%22', 'tweet_volume': None}, {'name': '#LigadoNaCN', 'url': 'http://twitter.com/search?q=%23LigadoNaCN', 'promoted_content': None, 'query': '%23LigadoNaCN', 'tweet_volume': None}, {'name': 'Michael Jordan', 'url': 'http://twitter.com/search?q=%22Michael+Jordan%22', 'promoted_content': None, 'query': '%22Michael+Jordan%22', 'tweet_volume': None}, {'name': 'Carta Capital', 'url': 'http://twitter.com/search?q=%22Carta+Capital%22', 'promoted_content': None, 'query': '%22Carta+Capital%22', 'tweet_volume': None}, {'name': 'Maracanaú', 'url': 'http://twitter.com/search?q=Maracana%C3%BA', 'promoted_content': None, 'query': 'Maracana%C3%BA', 'tweet_volume': None}, {'name': 'Carlos Bolsonaro', 'url': 'http://twitter.com/search?q=%22Carlos+Bolsonaro%22', 'promoted_content': None, 'query': '%22Carlos+Bolsonaro%22', 'tweet_volume': None}, {'name': 'Tasso Jereissati', 'url': 'http://twitter.com/search?q=%22Tasso+Jereissati%22', 'promoted_content': None, 'query': '%22Tasso+Jereissati%22', 'tweet_volume': None}, {'name': 'Jávier Godinho', 'url': 'http://twitter.com/search?q=%22J%C3%A1vier+Godinho%22', 'promoted_content': None, 'query': '%22J%C3%A1vier+Godinho%22', 'tweet_volume': None}, {'name': 'Tirei Fernando Haddad', 'url':
...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Vox Populi",
#     "url": "http://twitter.com/search?q=%22Vox+Populi%22",
#     "promoted_content": null,
#     "query": "%22Vox+Populi%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DiaDoProgramador",
#     "url": "http://twitter.com/search?q=%23DiaDoProgramador",
#     "promoted_content": null,
#     "query": "%23DiaDoProgramador",
#     "tweet_volume": null
#    },
#    {
#     "name": "#QuintaDetremuraSDV",
#     "url": "http://twitter.com/search?q=%23QuintaDetremuraSDV",
#     "promoted_content": null,
#     "query": "%23QuintaDetremuraSDV",
#     "tweet_volume": 13895
#    },
#    {
#     "name": "#SupernaturalDay",
#     "url": "http://twitter.com/search?q=%23SupernaturalDay",
#     "promoted_content": null,
#     "query": "%23SupernaturalDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HappyBirthdayNiall",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayNiall",
#     "promoted_content": null,
#     "query": "%23HappyBirthdayNiall",
#     "tweet_volume": 112387
#    },
#    {
#     "name": "Dias Toffoli",
#     "url": "http://twitter.com/search?q=%22Dias+Toffoli%22",
#     "promoted_content": null,
#     "query": "%22Dias+Toffoli%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LigadoNaCN",
#     "url": "http://twitter.com/search?q=%23LigadoNaCN",
#     "promoted_content": null,
#     "query": "%23LigadoNaCN",
#     "tweet_volume": null
#    },
#    {
#     "name": "Michael Jordan",
#     "url": "http://twitter.com/search?q=%22Michael+Jordan%22",
#     "promoted_content": null,
#     "query": "%22Michael+Jordan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Carta Capital",
#     "url": "http://twitter.com/search?q=%22Carta+Capital%22",
#     "promoted_content": null,
#     "query": "%22Carta+Capital%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Maracana\u00fa",
#     "url": "http://twitter.com/search?q=Maracana%C3%BA",
#     "promoted_content": null,
#     "query": "Maracana%C3%BA",
#     "tweet_volume": null
#    },
#    {
#     "name": "Carlos Bolsonaro",
#     "url": "http://twitter.com/search?q=%22Carlos+Bolsonaro%22",
#     "promoted_content": null,
#     "query": "%22Carlos+Bolsonaro%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tasso Jereissati",
#     "url": "http://twitter.com/search?q=%22Tasso+Jereissati%22",
#     "promoted_content": null,
#     "query": "%22Tasso+Jereissati%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "J\u00e1vier Godinho",
#     "url": "http://twitter.com/search?q=%22J%C3%A1vier+Godinho%22",
#     "promoted_content": null,
#     "query": "%22J%C3%A1vier+Godinho%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tirei Fernando Haddad",
#     "url": "http://twitter.com/search?q=%22Tirei+Fernando+Haddad%22",
#     "promoted_content": null,
#     "query": "%22Tirei+Fernando+Haddad%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tirei Henrique Meirelles",
#     "url": "http://twitter.com/search?q=%22Tirei+Henrique+Meirelles%22",
#     "promoted_content": null,
#     "query": "%22Tirei+Henrique+Meirelles%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dia Nacional da Cacha\u00e7a",
#     "url": "http://twitter.com/search?q=%22Dia+Nacional+da+Cacha%C3%A7a%22",
#     "promoted_content": null,
#     "query": "%22Dia+Nacional+da+Cacha%C3%A7a%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tirei Ciro Gomes",
#     "url": "http://twitter.com/search?q=%22Tirei+Ciro+Gomes%22",
#     "promoted_content": null,
#     "query": "%22Tirei+Ciro+Gomes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hyuna e o E'Dawn",
#     "url": "http://twitter.com/search?q=%22Hyuna+e+o+E%27Dawn%22",
#     "promoted_content": null,
#     "query": "%22Hyuna+e+o+E%27Dawn%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tirei Jo\u00e3o Amoedo",
#     "url": "http://twitter.com/search?q=%22Tirei+Jo%C3%A3o+Amoedo%22",
#     "promoted_content": null,
#     "query": "%22Tirei+Jo%C3%A3o+Amoedo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tirei Jos\u00e9 Maria Eymael",
#     "url": "http://twitter.com/search?q=%22Tirei+Jos%C3%A9+Maria+Eymael%22",
#     "promoted_content": null,
#     "query": "%22Tirei+Jos%C3%A9+Maria+Eymael%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "T\u00fanel Noel Rosa",
#     "url": "http://twitter.com/search?q=%22T%C3%BAnel+Noel+Rosa%22",
#     "promoted_content": null,
#     "query": "%22T%C3%BAnel+Noel+Rosa%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Corinthians",
#     "url": "http://twitter.com/search?q=Corinthians",
#     "promoted_content": null,
#     "query": "Corinthians",
#     "tweet_volume": 139970
#    },
#    {
#     "name": "F\u00e1bio",
#     "url": "http://twitter.com/search?q=F%C3%A1bio",
#     "promoted_content": null,
#     "query": "F%C3%A1bio",
#     "tweet_volume": 50840
#    },
#    {
#     "name": "C\u00e1ssio",
#     "url": "http://twitter.com/search?q=C%C3%A1ssio",
#     "promoted_content": null,
#     "query": "C%C3%A1ssio",
#     "tweet_volume": 32208
#    },
#    {
#     "name": "Barcos",
#     "url": "http://twitter.com/search?q=Barcos",
#     "promoted_content": null,
#     "query": "Barcos",
#     "tweet_volume": 12824
#    },
#    {
#     "name": "Superman",
#     "url": "http://twitter.com/search?q=Superman",
#     "promoted_content": null,
#     "query": "Superman",
#     "tweet_volume": 290209
#    },
#    {
#     "name": "El Salvador",
#     "url": "http://twitter.com/search?q=%22El+Salvador%22",
#     "promoted_content": null,
#     "query": "%22El+Salvador%22",
#     "tweet_volume": 15425
#    },
#    {
#     "name": "Dourado",
#     "url": "http://twitter.com/search?q=Dourado",
#     "promoted_content": null,
#     "query": "Dourado",
#     "tweet_volume": 20806
#    },
#    {
#     "name": "Clayson",
#     "url": "http://twitter.com/search?q=Clayson",
#     "promoted_content": null,
#     "query": "Clayson",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lana",
#     "url": "http://twitter.com/search?q=Lana",
#     "promoted_content": null,
#     "query": "Lana",
#     "tweet_volume": 91789
#    },
#    {
#     "name": "#GTFO",
#     "url": "http://twitter.com/search?q=%23GTFO",
#     "promoted_content": null,
#     "query": "%23GTFO",
#     "tweet_volume": 25205
#    },
#    {
#     "name": "#LuisaSonzaNoMorning",
#     "url": "http://twitter.com/search?q=%23LuisaSonzaNoMorning",
#     "promoted_content": null,
#     "query": "%23LuisaSonzaNoMorning",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MaisVoce",
#     "url": "http://twitter.com/search?q=%23MaisVoce",
#     "promoted_content": null,
#     "query": "%23MaisVoce",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BoulosResponde",
#     "url": "http://twitter.com/search?q=%23BoulosResponde",
#     "promoted_content": null,
#     "query": "%23BoulosResponde",
#     "tweet_volume": null
#    },
#    {
#     "name": "#bomdiafoxquinta",
#     "url": "http://twitter.com/search?q=%23bomdiafoxquinta",
#     "promoted_content": null,
#     "query": "%23bomdiafoxquinta",
#     "tweet_volume": null
#    },
#    {
#     "name": "#sabatinasnoGlobo",
#     "url": "http://twitter.com/search?q=%23sabatinasnoGlobo",
#     "promoted_content": null,
#     "query": "%23sabatinasnoGlobo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#98Esportes",
#     "url": "http://twitter.com/search?q=%2398Esportes",
#     "promoted_content": null,
#     "query": "%2398Esportes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AppleEvent",
#     "url": "http://twitter.com/search?q=%23AppleEvent",
#     "promoted_content": null,
#     "query": "%23AppleEvent",
#     "tweet_volume": 1053879
#    },
#    {
#     "name": "#FinalCantaComigo",
#     "url": "http://twitter.com/search?q=%23FinalCantaComigo",
#     "promoted_content": null,
#     "query": "%23FinalCantaComigo",
#     "tweet_volume": 13221
#    },
#    {
#     "name": "#\u00c9VerdadeEsseBilete",
#     "url": "http://twitter.com/search?q=%23%C3%89VerdadeEsseBilete",
#     "promoted_content": null,
#     "query": "%23%C3%89VerdadeEsseBilete",
#     "tweet_volume": 21700
#    },
#    {
#     "name": "#AnittaDigaNaoAoFascismo",
#     "url": "http://twitter.com/search?q=%23AnittaDigaNaoAoFascismo",
#     "promoted_content": null,
#     "query": "%23AnittaDigaNaoAoFascismo",
#     "tweet_volume": 11160
#    },
#    {
#     "name": "#MarinersApartmentComplex",
#     "url": "http://twitter.com/search?q=%23MarinersApartmentComplex",
#     "promoted_content": null,
#     "query": "%23MarinersApartmentComplex",
#     "tweet_volume": 18130
#    },
#    {
#     "name": "#AMAs",
#     "url": "http://twitter.com/search?q=%23AMAs",
#     "promoted_content": null,
#     "query": "%23AMAs",
#     "tweet_volume": 765399
#    },
#    {
#     "name": "#AHSApocalypse",
#     "url": "http://twitter.com/search?q=%23AHSApocalypse",
#     "promoted_content": null,
#     "query": "%23AHSApocalypse",
#     "tweet_volume": 126572
#    },
#    {
#     "name": "#ateofimdoanoeu",
#     "url": "http://twitter.com/search?q=%23ateofimdoanoeu",
#     "promoted_content": null,
#     "query": "%23ateofimdoanoeu",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-09-13T13:37:23Z",
#   "created_at": "2018-09-13T13:32:00Z",
#   "locations": [
#    {
#     "name": "Brazil",
#     "woeid": 23424768
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['bra'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['rio'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','bra','rio']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
    print()
# Out:
# ('----------', 'world')
# #quizjam_ko,#ケンミンショー,#あなたの誕生酒を教えて,#QuintaDetremuraSDV,#PSGxJordan,#uominiedonne,#NiñosHéroes,Merkez Bankası,#اكله_مستحيل_تاكلها,身長測定,#RoaldDahlDay2018,#DiaInternacionalDelChocolate,#SakaryaMeydanMuharebesi,#اليوم_العالمي_للقانون,#الخميس,#ArunJaitleyStepDown,#死ぬからの予測変換で生き返ってみせる,#DiaDelBibliotecario,#RahulMallyaLootedIndia,#마음당_절대_안치이는_요소,田中圭,#WorldSepsisDay,#عطنا_حكمه_حلوه_من_عندك,#ParoNacionalDocente,#MetinOktay,Franco del Valle,オォンオォン,Golden Sun,#جواز_الامارات_تاسع_اقوي_جواز,#DiaDoProgramador,#遺留捜査,#FelizJueves,#PoliceReforms,#TodoMexicano,アズレンPS4,#PlanPauvreté,#LabanPilipinas,#رساله_توجهها_للحاسد,#Moscovici,#وجهك_طويل_او_قصير_او_دايري,#ThursdayThoughts,#GTFO,#JokowiVsThanos,#PrimaryDay,#레진대표_미성년자착취,Salisbury,#13Sep,#TuQueEstudiaste,Vox Populi,#SupernaturalDay
#
# ('----------', 'bra')
# #QuintaDetremuraSDV,Tirei João Amoedo,#LuisaSonzaNoMorning,Carta Capital,Cássio,Hyuna e o E'Dawn,Carlos Bolsonaro,#LigadoNaCN,Tirei Fernando Haddad,Lana,#AHSApocalypse,Tirei Henrique Meirelles,Dias Toffoli,Barcos,#AnittaDigaNaoAoFascismo,Jávier Godinho,#DiaDoProgramador,#BoulosResponde,Túnel Noel Rosa,Tasso Jereissati,Superman,#bomdiafoxquinta,Clayson,#AMAs,El Salvador,#98Esportes,#AppleEvent,#FinalCantaComigo,#MarinersApartmentComplex,#ateofimdoanoeu,Dourado,#ÉVerdadeEsseBilete,#MaisVoce,Maracanaú,Michael Jordan,Dia Nacional da Cachaça,Tirei Ciro Gomes,#GTFO,Corinthians,Fábio,#sabatinasnoGlobo,Vox Populi,#SupernaturalDay,Tirei José Maria Eymael,#HappyBirthdayNiall
#
# ('----------', 'rio')
# #QuintaDetremuraSDV,Tirei João Amoedo,#LuisaSonzaNoMorning,Carta Capital,Cássio,Hyuna e o E'Dawn,Carlos Bolsonaro,#LigadoNaCN,Tirei Fernando Haddad,Lana,#AHSApocalypse,Tirei Henrique Meirelles,Dias Toffoli,Barcos,#AnittaDigaNaoAoFascismo,Jávier Godinho,#DiaDoProgramador,#BoulosResponde,Túnel Noel Rosa,Tasso Jereissati,Superman,#bomdiafoxquinta,Clayson,#AMAs,El Salvador,#98Esportes,#AppleEvent,#FinalCantaComigo,#MarinersApartmentComplex,#ateofimdoanoeu,Dourado,#ÉVerdadeEsseBilete,#MaisVoce,Maracanaú,Michael Jordan,Dia Nacional da Cachaça,Tirei Ciro Gomes,#GTFO,Corinthians,Fábio,#sabatinasnoGlobo,Vox Populi,#SupernaturalDay,Tirei José Maria Eymael,#HappyBirthdayNiall

# %%
print(( '='*10,'intersection of world and brazil'))
print((trends_set['world'].intersection(trends_set['bra'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['rio'].intersection(trends_set['bra'])))
# Out:
# ('==========', 'intersection of world and brazil')
# {'#DiaDoProgramador', '#QuintaDetremuraSDV', '#GTFO', 'Vox Populi', '#SupernaturalDay'}
# ('==========', 'intersection of us and san-diego')
# {'#LuisaSonzaNoMorning', 'Tirei João Amoedo', '#QuintaDetremuraSDV', 'Carta Capital', 'Cássio', "Hyuna e o E'Dawn", 'Carlos Bolsonaro', '#LigadoNaCN', 'Tirei Fernando Haddad', 'Lana', '#AHSApocalypse', 'Tirei Henrique Meirelles', 'Dias Toffoli', 'Barcos', '#AnittaDigaNaoAoFascismo', 'Jávier Godinho', '#DiaDoProgramador', '#Boul
jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dm-mc2aX4AArfzF.jpg', 'url': 'https://t.co/DsU9E7dBLE', 'display_url': 'pic.twitter.com/DsU9E7dBLE', 'expanded_url': 'https://twitter.com/autumvns/status/1040233059638030337/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 750, 'h': 558, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 750, 'h': 558, 'resize': 'fit'}, 'small': {'w': 680, 'h': 506, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'it', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1040206067538509824, 'in_reply_to_status_id_str': '1040206067538509824', 'in_reply_to_user_id': 1530629522, 'in_reply_to_user_id_str': '1530629522', 'in_reply_to_screen_name': 'autumvns', 'user': {'id': 1530629522, 'id_str': '1530629522', 'name': '🍂', 'screen_name': 'autumvns', 'location': 'Somewhere ', 'description': "Vi sono de’ giorni ch'io non posso fidarmi di me: un demone mi arde, mi ag ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 20

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['15. È molto bravo a mascherare il suo lato da fangirl\n\n#HappyBirthdayNiall https://t.co/DsU9E7dBLE',
#  'RT @justguccihes: niall horan por si só já é perfeito agora niall horan com a banheira do brasil pode ser o próprio paraíso \n\n#HappyBirthda…',
#  'RT @bichamalik: Eu me orgulho tanto de ser fã desse humaninho que nem consigo descrever. Parabéns menino Niall que tem o sorriso e a risada…',
#  'RT @NoControlProjec: Niall went from barely making it through auditions to having his album have over 1 billion streams &amp; playing at his dr…',
#  'RT @Iwtmwdicine: Niall Horan,como eu posso começar a explicar Niall Horan?\n#HappyBirthdayNiall https://t.co/EtnGIONJlK',
#  'só sei rir dessas pessoas que tão falando que o Niall tá com 25 anos \nGente, olha essa criança, ele só tem 5… https://t.co/ZM5qmSsnTr',
#  'RT @bxcktolouis: 25 anos do sorriso mais lindo que o mundo já viu \n#HappyBirthdayNiall https://t.co/0MYuO4rWlf',
#  'RT @lesliestyless09: happy birthday to my one and only Niall. You are the reason I get up every morning. Thank you for everything you do. I…',
#  'RT @StylesNordeste: Hj é o aniversário desse irlandês super amado e querido por todos. Não acredito que ele tá fazendo 25 anos, se foi onte…',
#  'RT @lxrryxmofo: Theo wishing Niall a happy birthday over the years is the cutest evolution😂😍\n#HappyBirthdayNiall https://t.co/JaJoYsdNjZ',
#  'Happy Birthday, Niall @NiallOfficial \nSpend very happy this day\nI know you won’t answer but I say I love you so muc… https://t.co/vba6j1Ksrp',
#  'RT @liamcombr: Hoje é dia de darmos os parabéns para um grande amigo do Liam. \nFeliz aniversário @NiallOfficial, nós te amamos e desejamos…',
#  'RT @Niall_1DGazela: Na minha cabeça o Niall sempre será uma criancinha, não dá pra aceitar que ele é um homem adulto agora... Iti Niall, te…',
#  'ITI MDS EU AMO ESSES BALÃOZINHOS AAA (vamos fingir que tem mesmo os balãozinho do tt no tt do niall)… https://t.co/IUpL137SQz',
#  "RT @OfficialNHHQ: A little surprise gift for @NiallOfficial , here's a little notebook to your fan's love letters 💌FOR YOU, We hope you get…",
#  'RT @homeftniall: Happy birthday to you Legend @NiallOfficial i hope you have a nice day, i love you x\n#HappyBirthdayNiall https://t.co/hgsz…',
#  'RT @niallusionado: THEO DESEJANDO PARABÉNS PRO NIALL\nOLHA A ROUPINHA E O CABELINHO EU VOU EXPLODIR DE TANTO AMOR #HappyBirthdayniall https:…',
#  'nunca deixem morrer niall e taylor na rep tour #HappyBirthdayNiall https://t.co/F1RFGbuGj7',
#  'RT @stylspidey: LOS CHICOS Y LAS FANS CANTÁNDOLE EN EL 2015 FELIZ CUMPLEAÑOS A NIALL /// NIALL COMO SOLISTA MIENTRAS LE CANTAN FELIZ CUMPLE…',
#  'RT @niallerdiaries: QUESTION II Is Niall 25 in your country yet??? \n\n#HappyBirthdayNiall https://t.co/50BoHVrodk']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Thu Sep 13 13:37:42 +0000 2018",
#  "id": 1040233059638030337,
#  "id_str": "1040233059638030337",
#  "text": "15. \u00c8 molto bravo a mascherare il suo lato da fangirl\n\n#HappyBirthdayNiall https://t.co/DsU9E7dBLE",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "HappyBirthdayNiall",
#     "indices": [
#      55,
#      74
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [],
#   "media": [
#    {
#     "id": 1040233035730444289,
#     "id_str": "1040233035730444289",
#     "indices": [
#      75,
#      98
#     ],
#     "media_url": "http://pbs.twimg.com/media/Dm-mb0JW4AE15zZ.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/Dm-mb0JW4AE15zZ.jpg",
#     "url": "https://t.co/DsU9E7dBLE",
#     "display_url": "pic.twitter.com/DsU9E7dBLE",
#     "expanded_url": "https://twitter.com/autumvns/status/1040233059638030337/photo/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 610,
#       "h": 605,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 610,
#       "h": 605,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 610,
#       "h": 605,
#       "resize": "fit"
#      }
#     }
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1040233035730444289,
#     "id_str": "1040233035730444289",
#     "indices": [
#      75,
#      98
#     ],
#     "media_url": "http://pbs.twimg.com/media/Dm-mb0JW4AE15zZ.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/Dm-mb0JW4AE15zZ.jpg",
#     "url": "https://t.co/DsU9E7dBLE",
#     "display_url": "pic.twitter.com/DsU9E7dBLE",
#     "expanded_url": "https://twitter.com/autumvns/status/1040233059638030337/photo/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 610,
#       "h": 605,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 610,
#       "h": 605,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 610,
#       "h": 605,
#       "resize": "fit"
#      }
#     }
#    },
#    {
#     "id": 1040233043502538755,
#     "id_str": "1040233043502538755",
#     "indices": [
#      75,
#      98
#     ],
#     "media_url": "http://pbs.twimg.com/media/Dm-mcRGXoAMwWiL.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/Dm-mcRGXoAMwWiL.jpg",
#     "url": "https://t.co/DsU9E7dBLE",
#     "display_url": "pic.twitter.com/DsU9E7dBLE",
#     "expanded_url": "https://twitter.com/autumvns/status/1040233059638030337/photo/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 480,
#       "h": 473,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 480,
#       "h": 473,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 480,
#       "h": 473,
#       "resize": "fit"
#      }
#     }
#    },
#    {
#     "id": 1040233049236140032,
#     "id_str": "1040233049236140032",
#     "indices": [
#      75,
#      98
#     ],
#     "media_url": "http://pbs.twimg.com/media/Dm-mcmdXcAARn0L.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/Dm-mcmdXcAARn0L.jpg",
#     "url": "https://t.co/DsU9E7dBLE",
#     "display_url": "pic.twitter.com/DsU9E7dBLE",
#     "expanded_url": "https://twitter.com/autumvns/status/1040233059638030337/photo/1",
#     "type": "photo",
#     "sizes": {
#      "small": {
#       "w": 460,
#       "h": 615,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 460,
#       "h": 615,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 460,
#       "h": 615,
#       "resize": "fit"
#      }
#     }
#    },
#    {
#     "id": 1040233053518553088,
#     "id_str": "1040233053518553088",
#     "indices": [
#      75,
#      98
#     ],
#     "media_url": "http://pbs.twimg.com/media/Dm-mc2aX4AArfzF.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/Dm-mc2aX4AArfzF.jpg",
#     "url": "https://t.co/DsU9E7dBLE",
#     "display_url": "pic.twitter.com/DsU9E7dBLE",
#     "expanded_url": "https://twitter.com/autumvns/status/1040233059638030337/photo/1",
#     "type": "photo",
#     "sizes": {
#      "large": {
#       "w": 750,
#       "h": 558,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 750,
#       "h": 558,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 506,
#       "resize": "fit"
#      }
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "it",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": 1040206067538509824,
#  "in_reply_to_status_id_str": "1040206067538509824",
#  "in_reply_to_user_id": 1530629522,
#  "in_reply_to_user_id_str": "1530629522",
#  "in_reply_to_screen_name": "autumvns",
#  "user": {
#   "id": 1530629522,
#   "id_str": "1530629522",
#   "name": "\ud83c\udf42",
#   "screen_name": "autumvns",
#   "location": "Somewhere ",
#   "description": "Vi sono de\u2019 giorni ch'io non posso fidarmi di me: un demone mi arde, mi agita, mi divora.",
#   "url": "https://t.co/sQKoxDf5Cz",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/sQKoxDf5Cz",
#       "expanded_url": "https://www.instagram.com/autumvn/?hl=it",
#       "display_url": "instagram.com/autumvn/?hl=it",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 2384,
#   "friends_count": 744,
#   "listed_count": 190,
#   "created_at": "Wed Jun 19 11:51:31 +0000 2013",
#   "favourites_count": 92206,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 124931,
#   "lang": "it",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "FFFFFF",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1039459860579082240/ixS6-hYf_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1039459860579082240/ixS6-hYf_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1530629522/1536667044",
#   "profile_link_color": "94D487",
#   "profile_sidebar_border_color": "FFFFFF",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "profile_text_color": "333333",
#   "profile_use_background_image": false,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "it"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 0
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "15. \u00c8 molto bravo a mascherare il suo lato da fangirl\n\n#HappyBirthdayNiall https://t.co/DsU9E7dBLE",
#  "RT @justguccihes: niall horan por si s\u00f3 j\u00e1 \u00e9 perfeito agora niall horan com a banheira do brasil pode ser o pr\u00f3prio para\u00edso \n\n#HappyBirthda\u2026",
#  "RT @bichamalik: Eu me orgulho tanto de ser f\u00e3 desse humaninho que nem consigo descrever. Parab\u00e9ns menino Niall que tem o sorriso e a risada\u2026",
#  "RT @NoControlProjec: Niall went from barely making it through auditions to having his album have over 1 billion streams &amp; playing at his dr\u2026",
#  "RT @Iwtmwdicine: Niall Horan,como eu posso come\u00e7ar a explicar Niall Horan?\n#HappyBirthdayNiall https://t.co/EtnGIONJlK"
# ]
# [
#  "justguccihes",
#  "bichamalik",
#  "NoControlProjec",
#  "Iwtmwdicine",
#  "bxcktolouis"
# ]
# [
#  "HappyBirthdayNiall",
#  "HappyBirthdayNiall",
#  "HappyBirthdayNiall",
#  "HappyBirthdayNiall",
#  "HappyBirthdayNiall"
# ]
# [
#  "15.",
#  "\u00c8",
#  "molto",
#  "bravo",
#  "a"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 15), ('Niall', 9), ('que', 8), ('you', 8), ('a', 7), ('#HappyBirthdayNiall', 7), ('o', 6), ('do', 5), ('é', 4), ('e', 4)]
#
# [('NiallOfficial', 4), ('justguccihes', 1), ('bichamalik', 1), ('NoControlProjec', 1), ('Iwtmwdicine', 1), ('bxcktolouis', 1), ('lesliestyless09', 1), ('StylesNordeste', 1), ('lxrryxmofo', 1), ('liamcombr', 1)]
#
# [('HappyBirthdayNiall', 7), ('HappyBirthdayniall', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
